# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
march12 = pd.read_csv('OCC/OCC1_2_Counter_03_2020_Filtered.gz', compression='gzip', header=None, sep=',', quotechar='"')
march34 = pd.read_csv('OCC/OCC3_4_Counter_03_2020_Filtered.gz', compression='gzip', header=None, sep=',', quotechar='"')
april12 = pd.read_csv('OCC/OCC1_2_Counter_04_2020_Filtered.gz', compression='gzip', header=None, sep=',', quotechar='"')
april34 = pd.read_csv('OCC/OCC3_4_Counter_04_2020_Filtered.gz', compression='gzip', header=None, sep=',', quotechar='"')
may12   = pd.read_csv('OCC/OCC1_2_Counter_05_2020_Filtered.gz', compression='gzip', header=None, sep=',', quotechar='"')
may34   = pd.read_csv('OCC/OCC3_4_Counter_05_2020_Filtered.gz', compression='gzip', header=None, sep=',', quotechar='"')

# %%
frames = [march12,april12,may12]
result12 = pd.concat(frames)
result12.shape
# Out:
# (317940, 7)

# %%
frames = [march34,april34,may34]
result34 = pd.concat(frames)
result34.shape
# Out:
# (317952, 7)

# %%
data_options=[
    'Diameter Front-End.Gy-CCR-Initial.request',
    'Diameter Front-End.Gy-CCR-Update.request',
    'Diameter Front-End.Gy-CCR-Termination.request'
]

# %%
result12=result12.loc[((result12[5].str.match(data_options[0])|result12[5].str.match(data_options[1]))|result12[5].str.match(data_options[2]))]
result12.drop([2,3,4], inplace=True , axis=1)
result12
# Out:
#                           0     1  \
# 0       2020-03-01 00:00:15  occ1
# 2       2020-03-01 00:00:15  occ1
# 4       2020-03-01 00:00:15  occ1
# 6       2020-03-01 00:00:15  occ2
# 8       2020-03-01 00:00:15  occ2
# ...                     ...   ...
# 107126  2020-05-31 23:55:00  occ1
# 107128  2020-05-31 23:55:00  occ1
# 107130  2020-05-31 23:55:00  occ2
# 107132  2020-05-31 23:55:00  occ2
# 107134  2020-05-31 23:55:00  occ2
#
#                                                     5           6
# 0           Diameter Front-End.Gy-CCR-Initial.request   113692437
# 2       Diameter Front-End.Gy-CCR-Termination.request   111986457
# 4            Diameter Front-End.Gy-CCR-Update.request   547572880
# 6           Diameter Front-End.Gy-CCR-Initial.request   113603759
# 8       Diameter Front-End.Gy-CCR-Termination.request   111940190
# ...                                               ...         ...
# 107126  Diameter Front-End.Gy-CCR-Termination.request   101248681
# 107128       Diameter Front-End.Gy-CCR-Update.request  1280271365
# 107130      Diameter Front-End.Gy-CCR-Initial.request   103189767
# 107132  Diameter Front-End.Gy-CCR-Termination.request   101179946
# 107134       Diameter Front-End.Gy-CCR-Update.request  1279836144
#
# [158970 rows x 4 columns]

# %%
result34=result34.loc[((result34[5].str.match(data_options[0])|result34[5].str.match(data_options[1]))|result34[5].str.match(data_options[2]))]
result34.drop([2,3,4], inplace=True , axis=1)
result34
# Out:
#                           0     1  \
# 0       2020-03-01 00:00:00  occ3
# 2       2020-03-01 00:00:00  occ3
# 4       2020-03-01 00:00:00  occ3
# 6       2020-03-01 00:00:00  occ4
# 8       2020-03-01 00:00:00  occ4
# ...                     ...   ...
# 107126  2020-05-31 23:55:00  occ3
# 107128  2020-05-31 23:55:00  occ3
# 107130  2020-05-31 23:55:00  occ4
# 107132  2020-05-31 23:55:00  occ4
# 107134  2020-05-31 23:55:00  occ4
#
#                                                     5           6
# 0           Diameter Front-End.Gy-CCR-Initial.request   124555229
# 2       Diameter Front-End.Gy-CCR-Termination.request   122609922
# 4            Diameter Front-End.Gy-CCR-Update.request   598896710
# 6           Diameter Front-End.Gy-CCR-Initial.request   124394663
# 8       Diameter Front-End.Gy-CCR-Termination.request   122459198
# ...                                               ...         ...
# 107126  Diameter Front-End.Gy-CCR-Termination.request   418862581
# 107128       Diameter Front-End.Gy-CCR-Update.request  3998884971
# 107130      Diameter Front-End.Gy-CCR-Initial.request   426158336
# 107132  Diameter Front-End.Gy-CCR-Termination.request   418350681
# 107134       Diameter Front-End.Gy-CCR-Update.request  3999689231
#
# [158976 rows x 4 columns]

# %%
uniqueValues =result12[0].unique()
df12 = pd.DataFrame(uniqueValues)
df12.set_index(0,inplace=True)

uniqueValues =result34[0].unique()
df34 = pd.DataFrame(uniqueValues)
df34.set_index(0,inplace=True)
df34
# Out:
# Empty DataFrame
# Columns: []
# Index: [2020-03-01 00:00:00, 2020-03-01 00:05:00, 2020-03-01 00:10:00, 2020-03-01 00:15:00, 2020-03-01 00:20:00, 2020-03-01 00:25:00, 2020-03-01 00:30:00, 2020-03-01 00:35:00, 2020-03-01 00:40:00, 2020-03-01 00:45:00, 2020-03-01 00:50:00, 2020-03-01 00:55:00, 2020-03-01 01:00:00, 2020-03-01 01:05:00, 2020-03-01 01:10:00, 2020-03-01 01:15:00, 2020-03-01 01:20:00, 2020-03-01 01:25:00, 2020-03-01 01:30:00, 2020-03-01 01:35:00, 2020-03-01 01:40:00, 2020-03-01 01:45:00, 2020-03-01 01:50:00, 2020-03-01 01:55:00, 2020-03-01 02:00:00, 2020-03-01 02:05:00, 2020-03-01 02:10:00, 2020-03-01 02:15:00, 2020-03-01 02:20:00, 2020-03-01 02:25:00, 2020-03-01 02:30:00, 2020-03-01 02:35:00, 2020-03-01 02:40:00, 2020-03-01 02:45:00, 2020-03-01 02:50:00, 2020-03-01 02:55:00, 2020-03-01 03:00:00, 2020-03-01 03:05:00, 2020-03-01 03:10:00, 2020-03-01 03:15:00, 2020-03-01 03:20:00, 2020-03-01 03:25:00, 2020-03-01 03:30:00, 2020-03-01 03:35:00, 2020-03-01 03:40:00, 2020-03-01 03:45:00, 2020-03-01 03:50:00, 2020-03-01 03:55:00, 2020-03-01 04:00:00, 2020-03-01 04:05:00, 2020-03-01 04:10:00, 2020-03-01 04:15:00, 2020-03-01 04:20:00, 2020-03-01 04:25:00, 2020-03-01 04:30:00, 2020-03-01 04:35:00, 2020-03-01 04:40:00, 2020-03-01 04:45:00, 2020-03-01 04:50:00, 2020-03-01 04:55:00, 2020-03-01 05:00:00, 2020-03-01 05:05:00, 2020-03-01 05:10:00, 2020-03-01 05:15:00, 2020-03-01 05:20:00, 2020-03-01 05:25:00, 2020-03-01 05:30:00, 2020-03-01 05:35:00, 2020-03-01 05:40:00, 2020-03-01 05:45:00, 2020-03-01 05:50:00, 2020-03-01 05:55:00, 2020-03-01 06:00:00, 2020-03-01 06:05:00, 2020-03-01 06:10:00, 2020-03-01 06:15:00, 2020-03-01 06:20:00, 2020-03-01 06:25:00, 2020-03-01 06:30:00, 2020-03-01 06:35:00, 2020-03-01 06:40:00, 2020-03-01 06:45:00, 2020-03-01 06:50:00, 2020-03-01 06:55:00, 2020-03-01 07:00:00, 2020-03-01 07:05:00, 2020-03-01 07:10:00, 2020-03-01 07:15:00, 2020-03-01 07:20:00, 2020-03-01 07:25:00, 2020-03-01 07:30:00, 2020-03-01 07:35:00, 2020-03-01 07:40:00, 2020-03-01 07:45:00, 2020-03-01 07:50:00, 2020-03-01 07:55:00, 2020-03-01 08:00:00, 2020-03-01 08:05:00, 2020-03-01 08:10:00, 2020-03-01 08:15:00, ...]
#
# [26496 rows x 0 columns]

# %%
copy_in=result12.loc[result12[1].str.match('occ1')&result12[5].str.match('Diameter Front-End.Gy-CCR-Initial.request')]
copy_tr=result12.loc[result12[1].str.match('occ1')&result12[5].str.match('Diameter Front-End.Gy-CCR-Termination.request')]
copy_ud=result12.loc[result12[1].str.match('occ1')&result12[5].str.match('Diameter Front-End.Gy-CCR-Update.request')]
copy_in.set_index(0,inplace=True)
copy_tr.set_index(0,inplace=True)
copy_ud.set_index(0,inplace=True)
df12['occ1_in']=copy_in[6]
df12['occ1_tr']=copy_tr[6]
df12['occ1_ud']=copy_ud[6]

copy_in=result12.loc[result12[1].str.match('occ2')&result12[5].str.match('Diameter Front-End.Gy-CCR-Initial.request')]
copy_tr=result12.loc[result12[1].str.match('occ2')&result12[5].str.match('Diameter Front-End.Gy-CCR-Termination.request')]
copy_ud=result12.loc[result12[1].str.match('occ2')&result12[5].str.match('Diameter Front-End.Gy-CCR-Update.request')]
copy_in.set_index(0,inplace=True)
copy_tr.set_index(0,inplace=True)
copy_ud.set_index(0,inplace=True)
df12['occ2_in']=copy_in[6]
df12['occ2_tr']=copy_tr[6]
df12['occ2_ud']=copy_ud[6]
df12
# Out:
#                        occ1_in    occ1_tr     occ1_ud    occ2_in    occ2_tr  \
# 0
# 2020-03-01 00:00:15  113692437  111986457   547572880  113603759  111940190
# 2020-03-01 00:05:15  113701351  111995688   547638843  113612549  111949303
# 2020-03-01 00:10:15  113709450  112004158   547701494  113620614  111957774
# 2020-03-01 00:15:15  113717059  112012228   547763211  113628381  111965944
# 2020-03-01 00:20:15  113724618  112020377   547822718  113635872  111973979
# ...                        ...        ...         ...        ...        ...
# 2020-05-31 23:35:00  103326689  101216780  1279715354  103159310  101147691
# 2020-05-31 23:40:00  103334729  101225309  1279857342  103167368  101156218
# 2020-05-31 23:45:00  103342312  101233392  1279998645  103175036  101164370
# 2020-05-31 23:50:00  103349556  101241066  1280137295  103182623  101172388
# 2020-05-31 23:55:00  103356743  101248681  1280271365  103189767  101179946
#
#                         occ2_ud
# 0
# 2020-03-01 00:00:15   547427837
# 2020-03-01 00:05:15   547493584
# 2020-03-01 00:10:15   547555517
# 2020-03-01 00:15:15   547616757
# 2020-03-01 00:20:15   547675938
# ...                         ...
# 2020-05-31 23:35:00  1279278094
# 2020-05-31 23:40:00  1279421406
# 2020-05-31 23:45:00  1279562322
# 2020-05-31 23:50:00  1279700962
# 2020-05-31 23:55:00  1279836144
#
# [26495 rows x 6 columns]

# %%
copy_in=result34.loc[result34[1].str.match('occ3')&result34[5].str.match('Diameter Front-End.Gy-CCR-Initial.request')]
copy_tr=result34.loc[result34[1].str.match('occ3')&result34[5].str.match('Diameter Front-End.Gy-CCR-Termination.request')]
copy_ud=result34.loc[result34[1].str.match('occ3')&result34[5].str.match('Diameter Front-End.Gy-CCR-Update.request')]
copy_in.set_index(0,inplace=True)
copy_tr.set_index(0,inplace=True)
copy_ud.set_index(0,inplace=True)
df34['occ3_in']=copy_in[6]
df34['occ3_tr']=copy_tr[6]
df34['occ3_ud']=copy_ud[6]

copy_in=result34.loc[result34[1].str.match('occ4')&result34[5].str.match('Diameter Front-End.Gy-CCR-Initial.request')]
copy_tr=result34.loc[result34[1].str.match('occ4')&result34[5].str.match('Diameter Front-End.Gy-CCR-Termination.request')]
copy_ud=result34.loc[result34[1].str.match('occ4')&result34[5].str.match('Diameter Front-End.Gy-CCR-Update.request')]
copy_in.set_index(0,inplace=True)
copy_tr.set_index(0,inplace=True)
copy_ud.set_index(0,inplace=True)
df34['occ4_in']=copy_in[6]
df34['occ4_tr']=copy_tr[6]
df34['occ4_ud']=copy_ud[6]
df34
# Out:
#                        occ3_in    occ3_tr     occ3_ud    occ4_in    occ4_tr  \
# 0
# 2020-03-01 00:00:00  124555229  122609922   598896710  124394663  122459198
# 2020-03-01 00:05:00  124564435  122619347   598963008  124403812  122468583
# 2020-03-01 00:10:00  124572498  122627813   599026196  124412020  122477167
# 2020-03-01 00:15:00  124580442  122636158   599087635  124419698  122485262
# 2020-03-01 00:20:00  124587897  122644228   599147516  124427149  122493359
# ...                        ...        ...         ...        ...        ...
# 2020-05-31 23:35:00  426161118  418830493  3998323229  426128509  418319007
# 2020-05-31 23:40:00  426169277  418839160  3998466124  426136600  418327560
# 2020-05-31 23:45:00  426176885  418847209  3998609626  426144243  418335697
# 2020-05-31 23:50:00  426184302  418855056  3998749274  426151532  418343427
# 2020-05-31 23:55:00  426191375  418862581  3998884971  426158336  418350681
#
#                         occ4_ud
# 0
# 2020-03-01 00:00:00   598545458
# 2020-03-01 00:05:00   598611216
# 2020-03-01 00:10:00   598673779
# 2020-03-01 00:15:00   598734437
# 2020-03-01 00:20:00   598793534
# ...                         ...
# 2020-05-31 23:35:00  3999130060
# 2020-05-31 23:40:00  3999271815
# 2020-05-31 23:45:00  3999415276
# 2020-05-31 23:50:00  3999554501
# 2020-05-31 23:55:00  3999689231
#
# [26496 rows x 6 columns]

# %%
df12['occ1_in']=df12['occ1_in'].diff()
df12['occ1_tr']=df12['occ1_tr'].diff()
df12['occ1_ud']=df12['occ1_ud'].diff()
df12['occ2_in']=df12['occ2_in'].diff()
df12['occ2_tr']=df12['occ2_tr'].diff()
df12['occ2_ud']=df12['occ2_ud'].diff()
df12
# Out:
#                      occ1_in  occ1_tr   occ1_ud  occ2_in  occ2_tr   occ2_ud
# 0
# 2020-03-01 00:00:15      NaN      NaN       NaN      NaN      NaN       NaN
# 2020-03-01 00:05:15   8914.0   9231.0   65963.0   8790.0   9113.0   65747.0
# 2020-03-01 00:10:15   8099.0   8470.0   62651.0   8065.0   8471.0   61933.0
# 2020-03-01 00:15:15   7609.0   8070.0   61717.0   7767.0   8170.0   61240.0
# 2020-03-01 00:20:15   7559.0   8149.0   59507.0   7491.0   8035.0   59181.0
# ...                      ...      ...       ...      ...      ...       ...
# 2020-05-31 23:35:00   8467.0   8907.0  147438.0   8532.0   8969.0  147029.0
# 2020-05-31 23:40:00   8040.0   8529.0  141988.0   8058.0   8527.0  143312.0
# 2020-05-31 23:45:00   7583.0   8083.0  141303.0   7668.0   8152.0  140916.0
# 2020-05-31 23:50:00   7244.0   7674.0  138650.0   7587.0   8018.0  138640.0
# 2020-05-31 23:55:00   7187.0   7615.0  134070.0   7144.0   7558.0  135182.0
#
# [26495 rows x 6 columns]

# %%
df34['occ3_in']=df34['occ3_in'].diff()
df34['occ3_tr']=df34['occ3_tr'].diff()
df34['occ3_ud']=df34['occ3_ud'].diff()
df34['occ4_in']=df34['occ4_in'].diff()
df34['occ4_tr']=df34['occ4_tr'].diff()
df34['occ4_ud']=df34['occ4_ud'].diff()

df34
# Out:
#                      occ3_in  occ3_tr   occ3_ud  occ4_in  occ4_tr   occ4_ud
# 0
# 2020-03-01 00:00:00      NaN      NaN       NaN      NaN      NaN       NaN
# 2020-03-01 00:05:00   9206.0   9425.0   66298.0   9149.0   9385.0   65758.0
# 2020-03-01 00:10:00   8063.0   8466.0   63188.0   8208.0   8584.0   62563.0
# 2020-03-01 00:15:00   7944.0   8345.0   61439.0   7678.0   8095.0   60658.0
# 2020-03-01 00:20:00   7455.0   8070.0   59881.0   7451.0   8097.0   59097.0
# ...                      ...      ...       ...      ...      ...       ...
# 2020-05-31 23:35:00   8520.0   8991.0  148798.0   8245.0   8689.0  148220.0
# 2020-05-31 23:40:00   8159.0   8667.0  142895.0   8091.0   8553.0  141755.0
# 2020-05-31 23:45:00   7608.0   8049.0  143502.0   7643.0   8137.0  143461.0
# 2020-05-31 23:50:00   7417.0   7847.0  139648.0   7289.0   7730.0  139225.0
# 2020-05-31 23:55:00   7073.0   7525.0  135697.0   6804.0   7254.0  134730.0
#
# [26496 rows x 6 columns]

# %%
df12['Traffic']=df12['occ1_in']+df12['occ1_tr']+df12['occ1_ud']+df12['occ2_in']+df12['occ2_tr']+df12['occ2_ud']
df12['Traffic'][0]=0
df12.reset_index(drop=True, inplace=True)
uniqueValues =result12[0].unique()
df12['Date']=uniqueValues
df12[['Date','Time']] = df12.Date.str.split(expand=True)
df12
# Out:
#        occ1_in  occ1_tr   occ1_ud  occ2_in  occ2_tr   occ2_ud   Traffic  \
# 0          NaN      NaN       NaN      NaN      NaN       NaN       0.0
# 1       8914.0   9231.0   65963.0   8790.0   9113.0   65747.0  167758.0
# 2       8099.0   8470.0   62651.0   8065.0   8471.0   61933.0  157689.0
# 3       7609.0   8070.0   61717.0   7767.0   8170.0   61240.0  154573.0
# 4       7559.0   8149.0   59507.0   7491.0   8035.0   59181.0  149922.0
# ...        ...      ...       ...      ...      ...       ...       ...
# 26490   8467.0   8907.0  147438.0   8532.0   8969.0  147029.0  329342.0
# 26491   8040.0   8529.0  141988.0   8058.0   8527.0  143312.0  318454.0
# 26492   7583.0   8083.0  141303.0   7668.0   8152.0  140916.0  313705.0
# 26493   7244.0   7674.0  138650.0   7587.0   8018.0  138640.0  307813.0
# 26494   7187.0   7615.0  134070.0   7144.0   7558.0  135182.0  298756.0
#
#              Date      Time
# 0      2020-03-01  00:00:15
# 1      2020-03-01  00:05:15
# 2      2020-03-01  00:10:15
# 3      2020-03-01  00:15:15
# 4      2020-03-01  00:20:15
# ...           ...       ...
# 26490  2020-05-31  23:35:00
# 26491  2020-05-31  23:40:00
# 26492  2020-05-31  23:45:00
# 26493  2020-05-31  23:50:00
# 26494  2020-05-31  23:55:00
#
# [26495 rows x 9 columns]

# %%
temp=result12.loc[result12[0].str.contains('2020-04-28 13:40:00')]
temp
df12['occ1_in'][16867]=temp[6][95268]
df12['occ1_tr'][16867]=temp[6][95270]
df12['occ1_ud'][16867]=temp[6][95272]
df12['occ2_in'][16867]=temp[6][95274]
df12['occ2_tr'][16867]=temp[6][95276]
df12['occ2_ud'][16867]=temp[6][95278]
df12['Traffic'][16867]=temp[6].sum()

# %%
df34['Traffic']=df34['occ3_in']+df34['occ3_tr']+df34['occ3_ud']+df34['occ4_in']+df34['occ4_tr']+df34['occ4_ud']
df34['Traffic'][0]=0
df34.reset_index(drop=True, inplace=True)
uniqueValues =result34[0].unique()
df34['Date']=uniqueValues
df34[['Date','Time']] = df34.Date.str.split(expand=True)
df34
# Out:
#        occ3_in  occ3_tr   occ3_ud  occ4_in  occ4_tr   occ4_ud   Traffic  \
# 0          NaN      NaN       NaN      NaN      NaN       NaN       0.0
# 1       9206.0   9425.0   66298.0   9149.0   9385.0   65758.0  169221.0
# 2       8063.0   8466.0   63188.0   8208.0   8584.0   62563.0  159072.0
# 3       7944.0   8345.0   61439.0   7678.0   8095.0   60658.0  154159.0
# 4       7455.0   8070.0   59881.0   7451.0   8097.0   59097.0  150051.0
# ...        ...      ...       ...      ...      ...       ...       ...
# 26491   8520.0   8991.0  148798.0   8245.0   8689.0  148220.0  331463.0
# 26492   8159.0   8667.0  142895.0   8091.0   8553.0  141755.0  318120.0
# 26493   7608.0   8049.0  143502.0   7643.0   8137.0  143461.0  318400.0
# 26494   7417.0   7847.0  139648.0   7289.0   7730.0  139225.0  309156.0
# 26495   7073.0   7525.0  135697.0   6804.0   7254.0  134730.0  299083.0
#
#              Date      Time
# 0      2020-03-01  00:00:00
# 1      2020-03-01  00:05:00
# 2      2020-03-01  00:10:00
# 3      2020-03-01  00:15:00
# 4      2020-03-01  00:20:00
# ...           ...       ...
# 26491  2020-05-31  23:35:00
# 26492  2020-05-31  23:40:00
# 26493  2020-05-31  23:45:00
# 26494  2020-05-31  23:50:00
# 26495  2020-05-31  23:55:00
#
# [26496 rows x 9 columns]

# %%
uniqueValues =df34['Date'].unique()
data = pd.DataFrame(uniqueValues)

def traffic(a):
    return (df12.loc[df12['Date']==a]['Traffic'].sum()+df34.loc[df34['Date']==a]['Traffic'].sum())
  

data['Count']=data.apply(lambda x: traffic(x[0]),axis=1)


data
# Out:
#              0        Count
# 0   2020-03-01  115267614.0
# 1   2020-03-02  113664571.0
# 2   2020-03-03  112104110.0
# 3   2020-03-04  160144899.0
# 4   2020-03-05  171405995.0
# ..         ...          ...
# 87  2020-05-27  191184284.0
# 88  2020-05-28  185071429.0
# 89  2020-05-29  182733931.0
# 90  2020-05-30  185886233.0
# 91  2020-05-31  184809579.0
#
# [92 rows x 2 columns]

# %%
plt.figure(figsize=(14,6))
plt.title("Line Chart for OCC  Traffic")
sns.lineplot(data=data['Count'], label="Voice Traffic")
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
data.plot.bar(x=0, y="Count", rot=70, title="OCC Traffic",figsize=(20,6))
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')
