# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
roam = pd.read_excel('ROAMING_DATA_FEB_MAR_APR_MAY2020.xlsx')
# Out:
# 0     2020-02-01
# 1     2020-02-01
# 2     2020-02-01
# 3     2020-02-01
# 4     2020-02-02
#          ...
# 479   2020-05-30
# 480   2020-05-31
# 481   2020-05-31
# 482   2020-05-31
# 483   2020-05-31
# Name: TRANSDATE, Length: 484, dtype: datetime64[ns]

# %%
types=[
    'GPRS',
    'Mobile Terminating Call',
    'Mobile originated Call',
    'Short Message Originating Call'
]

# %%
gprs=roam.loc[roam['CALL TYPE DESCRIPTION'].str.match(types[0])]
gprs.drop(['CALLTYPE', 'CALL TYPE DESCRIPTION','CDR COUNT'], inplace=True , axis=1)
mtc=roam.loc[roam['CALL TYPE DESCRIPTION'].str.match(types[1])]
mtc.drop(['CALLTYPE', 'CALL TYPE DESCRIPTION','CDR COUNT'], inplace=True , axis=1)
moc=roam.loc[roam['CALL TYPE DESCRIPTION'].str.match(types[2])]
moc.drop(['CALLTYPE', 'CALL TYPE DESCRIPTION','CDR COUNT'], inplace=True , axis=1)
smoc=roam.loc[roam['CALL TYPE DESCRIPTION'].str.match(types[3])]
smoc.drop(['CALLTYPE', 'CALL TYPE DESCRIPTION','CDR COUNT'], inplace=True , axis=1)
smoc
# Out:
#      TRANSDATE  VOLUME
# 2   2020-02-01    7264
# 6   2020-02-02    7664
# 10  2020-02-03    8155
# 14  2020-02-04    8131
# 18  2020-02-05    7629
# ..         ...     ...
# 466 2020-05-27    3761
# 470 2020-05-28    3682
# 474 2020-05-29    3585
# 478 2020-05-30    3572
# 482 2020-05-31    3283
#
# [121 rows x 2 columns]

# %%
gprs.plot.bar(x=0, y="VOLUME", rot=70, title="GPRS",figsize=(30,6))
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
mtc.plot.bar(x=0, y="VOLUME", rot=70, title="GPRS",figsize=(30,6))
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
moc.plot.bar(x=0, y="VOLUME", rot=70, title="GPRS",figsize=(30,6))
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
smoc.plot.bar(x=0, y="VOLUME", rot=70, title="GPRS",figsize=(30,6))
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')
